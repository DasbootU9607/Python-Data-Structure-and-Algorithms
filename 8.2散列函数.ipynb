# %% [markdown]
# ### 散列函数（哈希函数）

# %%
hash_object = hashlib.md5(b"hello word!")
md5_hash = hash_object.hexdigest()
print(md5_hash)
# Out:
# 39505368546302be2704b3d53b24203c

# %%
def hash(astring,tablesize):
    sum=0
    for pos in range(len(astring)):
        sum+=ord(astring[pos])
    return sum%tablesize
